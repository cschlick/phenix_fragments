# %%
import elbow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_33301/2200703048.py in <module>
# ----> 1 import elbow
#
# ModuleNotFoundError: No module named 'elbow'

# %%
from frag.mol.mols import Mol

# %%
import os
os.environ["MMTBX_CCP4_MONOMER_LIB"] = "/net/cci-filer3/home/cschlick/software/phenix/modules/chem_data/geostd"

# %%
mol = Mol.from_file_via_cctbx("1yjp.cif")

# %%
mol = Mol.from_file_geocif("acy_prot.cif")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_33605/3026767521.py in <module>
# ----> 1 mol = Mol.from_file_geocif("acy_prot.cif")
#
# ~/software/phenix/conda_base/lib/python3.7/site-packages/frag/mol/mols.py in from_file_geocif(cls, file)
#     199     cif_dict = load_cif_file(file)
#     200     assert ".cif" in file.suffixes, "Only cif supported"
# --> 201     cif_format = guess_cif_format(cif_dict)
#     202     assert cif_format == "geocif", "Only geostd cif (restraints) supported"
#     203     mol_input = MolInputGeo(cif_dict,file=file)
#
# ~/software/phenix/conda_base/lib/python3.7/site-packages/frag/mol/cif.py in guess_cif_format(cif_dict)
#     140       return "geocif"
#     141     else:
# --> 142       assert False, "Unable to guess cif format"
#     143   else:
#     144     assert False, "Unable to guess cif format"
#
# AssertionError: Unable to guess cif format

# %%
for bond in mol.bonds:
  for atom in bond.atoms:
    pass

# %%
mol.bonds.df
# Out:
#    bond_type  distance  distance_ideal
# 0     single  1.507075          1.4510
# 1     single  1.505882          1.5160
# 2     single  1.245259          1.2310
# 3     single  1.331791          1.3308
# 4     single  1.474502          1.4560
# 5     single  1.498392          1.5236
# 6     single  1.508551          1.5293
# 7     single  1.233367          1.2341
# 8     single  1.330452          1.3305
# 9     single  1.498121          1.5160
# 10    single  1.242048          1.2310
# 11    single  1.336671          1.3280
# 12    single  1.454812          1.4564
# 13    single  1.530184          1.5213
# 14    single  1.546687          1.5317
# 15    single  1.240672          1.2356
# 16    single  1.339226          1.3317
# 17    single  1.539835          1.5160
# 18    single  1.242390          1.2310
# 19    single  1.336722          1.3280
# 20    single  1.484629          1.4601
# 21    single  1.552561          1.5224
# 22    single  1.534838          1.5295
# 23    single  1.242353          1.2354
# 24    single  1.321467          1.3296
# 25    single  1.543712          1.5200
# 26    single  1.533688          1.5160
# 27    single  1.251390          1.2310
# 28    single  1.358017          1.3280
# 29    single  1.458910          1.4564
# 30    single  1.524352          1.5221
# 31    single  1.532491          1.5306
# 32    single  1.239953          1.2357
# 33    single  1.322525          1.3305
# 34    single  1.530953          1.5200
# 35    single  1.493576          1.5160
# 36    single  1.230091          1.2310
# 37    single  1.347879          1.3280
# 38    single  1.466032          1.4618
# 39    single  1.503983          1.5256
# 40    single  1.519479          1.5268
# 41    single  1.238083          1.2351
# 42    single  1.326766          1.3290
# 43    single  1.509264          1.5160
# 44    single  1.228834          1.2310
# 45    single  1.309915          1.3280
# 46    single  1.478419          1.4580
# 47    single  1.513770          1.5250
# 48    single  1.522743          1.5300
# 49    single  1.234157          1.2310
# 50    single  1.242891          1.2310
# 51    single  1.500467          1.5120
# 52    single  1.388264          1.3890
# 53    single  1.397972          1.3890
# 54    single  1.401107          1.3820
# 55    single  1.378357          1.3820
# 56    single  1.386749          1.3780
# 57    single  1.391418          1.3780
# 58    single  1.368269          1.3760
